# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import re
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
response = requests.get("https://www.residentadvisor.net/events/us/newyork")
soup = BeautifulSoup(response.content, 'html.parser')

# %%
event_listings = soup.find('div', id="event-listing")

# %%
entries = event_listings.findAll('li')
print(len(entries), entries[2])
# Out:
# 124 <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-08T00:00" itemprop="startDate">2019-07-08T00:00</time></span><a href="/events/1287650"><img height="76" src="/images/events/flyer/2019/7/us-0708-1287650-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1287650" itemprop="url" title="Event details of Big Eats">Big Eats</a> <span>at <a href="/club.aspx?id=128789">Jupiter Disco</a></span></h1><div class="grey event-lineup">Omo Igi, Ned Nice, Slauson Malone</div></div></article></li>

# %%
rows = []
for entry in entries:
    #Is it a date? If so, set current date.
    date = entry.find('p', class_="eventDate date")
    event = entry.find('h1', class_="event-title")
    if event:
        details = event.text.split(' at ')
        event_name = details[0].strip()
        venue = details[1].strip()
        try:
            n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
        except:
            n_attendees = np.nan
        rows.append([event_name, venue, cur_date, n_attendees])
    elif date:
        cur_date = date.text
    else:
        continue
df = pd.DataFrame(rows)
df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
df.head()
# Out:
#                                          Event_Name                  Venue  \
# 0                                       Rosa Perreo           House Of Yes
# 1                                          Big Eats          Jupiter Disco
# 2  Body Music Therapy: Yaya Yoga with _ \ • / _ Eon               Nowadays
# 3        Epilogue II feat. Shyboi and Joey Quiñones  Bossa Nova Civic Club
# 4                             MASHT NYC - Kassebaum          Jupiter Disco
#
#            Event_Date  Number_of_Attendees
# 0  Mon, 08 Jul 2019 /                  2.0
# 1  Mon, 08 Jul 2019 /                  NaN
# 2  Tue, 09 Jul 2019 /                  6.0
# 3  Tue, 09 Jul 2019 /                 20.0
# 4  Tue, 09 Jul 2019 /                 12.0

# %%
def scrape_events(events_page_url):
    #Your code here
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    event_listings = soup.find('div', id="event-listing")
    entries = event_listings.findAll('li')
    rows = []
    for entry in entries:
        #Is it a date? If so, set current date.
        date = entry.find('p', class_="eventDate date")
        event = entry.find('h1', class_="event-title")
        if event:
            details = event.text.split(' at ')
            event_name = details[0].strip()
            venue = details[1].strip()
            try:
                n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
            except:
                n_attendees = np.nan
            rows.append([event_name, venue, cur_date, n_attendees])
        elif date:
            cur_date = date.text
        else:
            continue
    df = pd.DataFrame(rows)
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    df.head()
    return df

# %%
events_page_url = "https://www.residentadvisor.net/events/us/newyork"
scrape_events(events_page_url)
# Out:
#                                             Event_Name  \
# 0                                          Rosa Perreo
# 1                                             Big Eats
# 2     Body Music Therapy: Yaya Yoga with _ \ • / _ Eon
# 3           Epilogue II feat. Shyboi and Joey Quiñones
# 4                                MASHT NYC - Kassebaum
# 5    Jeremy Black (Live) + Chris Egan (Live) + Dave...
# 6    Tempo with Fabio Slider, Michele Preda, Pablo ...
# 7    Kiss & Tell: Juan Maclean, Young Male, Xenia, ...
# 8     Body Music Therapy: Yaya Yoga with _ \ • / _ Eon
# 9          Exile: Rabia Khan / Rob Seurat / Din / Yuri
# 10                               Open Decks Session 71
# 11                                    Soulful Sessions
# 12         Kaeshi Chai's Weekly Djam NYC Party Returns
# 13                                   Hugo x Carly Zeng
# 14   Morgana [free entry]: Steve Bug, Jimpster, Joy...
# 15      Betty Ford presents: Ed Rush & Optical, Adred.
# 16                Rena Anakwe: Fast Forward to Silence
# 17                      Under with Jonny Sum and Emjay
# 18                                    Soulful Sessions
# 19                    Tropical Past & Future Residency
# 20                                         Bonus Beats
# 21                      DJ Fire & DJ Healthy All Night
# 22                                      Near the Stars
# 23                                         Mel Debarge
# 24   TBA Night with Mike Terra, Zeni Karpuzi, Andre...
# 25   Gorgon City Pres. Realm with Lee Foss, Totally...
# 26   X-TRA.SERVICES [1 YEAR] — Hadone, JKS, vveiss,...
# 27   Golden Record NYC presents Fred P (6 Hour set)...
# 28                       Ben Sims / Tapefeed / Ne/Re/A
# 29            Friday: Justin Carter and Shanti Celeste
# ..                                                 ...
# 81   Circle Line Sightseeing Cruises‎ Summer Series...
# 82                The Greatest Day Ever! Festival 2019
# 83                               Sleepy & Boo + guests
# 84   PFR x Jupiter Disco: Rees, Paurro, The Space W...
# 85                                            Resolute
# 86   Mesma Records with Mayssam / Moma Ready / Gamm...
# 87   Feel Free #009 - Grand Atrium / Buskko + Numa ...
# 88                                    Afro Latino Fest
# 89          Detour & Co. with Davis Galvin, Alex Price
# 90                            Maurice Fulton all Night
# 91                                       Geometry Wars
# 92   Saturday Sessions: Dale Howard NY Debut //Bros...
# 93                 Ride The Wave Midnight Yacht Cruise
# 94     Harold Budd: The Candlelight Concerts (Night 2)
# 95                               Toribio x Bryce David
# 96                      Standard Deviation - Diffusion
# 97            Happy Family Night Market Music Festival
# 98                              Blaqwell / Djette Kiwi
# 99                        Deepbeats // Deep House Yoga
# 100                           Zero presents... Pirates
# 101   Mister Sunday: Eamon Harkin and Physical Therapy
# 102  Yayo presents: La Fête National Brunch with Cl...
# 103                                        French Kiss
# 104                Good Room presents: FIXED Weekender
# 105               The Greatest Day Ever! Festival 2019
# 106                                         Earthbound
# 107                    Pretty Hybrids Early Nite Party
# 108                    Sunday Soiree: Amo, Allan, Niko
# 89                       Elsewhere  Sat, 13 Jul 2019 /                  NaN
# 90                         Le Bain  Sat, 13 Jul 2019 /                  NaN
# 91                     Wonderville  Sat, 13 Jul 2019 /                  NaN
# 92             230 Fifth Penthouse  Sat, 13 Jul 2019 /                  NaN
# 93             Harbor Lights Yacht  Sat, 13 Jul 2019 /                  NaN
# 94   St. George's Episcopal Church  Sat, 13 Jul 2019 /                  NaN
# 95                  Black Flamingo  Sat, 13 Jul 2019 /                  NaN
# 96                    TBA Brooklyn  Sat, 13 Jul 2019 /                  NaN
# 97              Abrons Arts Center  Sat, 13 Jul 2019 /                  NaN
# 98                   Paradise Club  Sat, 13 Jul 2019 /                  NaN
# 99                    House Of Yes  Sat, 13 Jul 2019 /                  NaN
# 100            Circle Line Cruises  Sun, 14 Jul 2019 /                151.0
# 101                       Nowadays  Sun, 14 Jul 2019 /                 40.0
# 102              Hornblower Cruise  Sun, 14 Jul 2019 /                  4.0
# 103                   House Of Yes  Sun, 14 Jul 2019 /                  1.0
# 104               Glen Falls House  Sun, 14 Jul 2019 /                  NaN
# 105                   Coney Island  Sun, 14 Jul 2019 /                  NaN
# 106                 public records  Sun, 14 Jul 2019 /                  NaN
# 107          Bossa Nova Civic Club  Sun, 14 Jul 2019 /                  NaN
# 108                   TBA Brooklyn  Sun, 14 Jul 2019 /                  NaN
# 109               Le Poisson Rouge  Sun, 14 Jul 2019 /                  NaN
# 110              Ford Amphitheater  Sun, 14 Jul 2019 /                  NaN
#
# [111 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
# Out:
# '/events/us/newyork/week/2019-07-15'

# %%
def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net" + url_ext
    #Your code here
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
dfs = []
total_rows = 0
cur_url = "https://www.residentadvisor.net/events/us/newyork"
while total_rows <= 450:
    df = scrape_events(cur_url)
    dfs.append(df)
    total_rows += len(df)
    cur_url = next_page(cur_url)
    time.sleep(.2)
df = pd.concat(dfs)
df = df.iloc[:450]
print(len(df))
df.head()
# Out:
# 450
#                                          Event_Name                  Venue  \
# 0                                       Rosa Perreo           House Of Yes
# 1                                          Big Eats          Jupiter Disco
# 2  Body Music Therapy: Yaya Yoga with _ \ • / _ Eon               Nowadays
# 3        Epilogue II feat. Shyboi and Joey Quiñones  Bossa Nova Civic Club
# 4                             MASHT NYC - Kassebaum          Jupiter Disco
#
#            Event_Date  Number_of_Attendees
# 0  Mon, 08 Jul 2019 /                  2.0
# 1  Mon, 08 Jul 2019 /                  NaN
# 2  Tue, 09 Jul 2019 /                  6.0
# 3  Tue, 09 Jul 2019 /                 20.0
# 4  Tue, 09 Jul 2019 /                 12.0

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
